# %%
#내 드라이브에 있는 파일 google drive에 업로드
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-453b24e8-84f7-4a27-830e-a33bf4f97f11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-453b24e8-84f7-4a27-830e-a33bf4f97f11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_text_5.txt to test_text_5.txt

# %%
import io
import os
import pandas as pd
import numpy as np

file_name = list(myfile.keys())[0]

texts = open(file_name,"r", encoding='euc-kr')

# %%
# !pip install git+https://github.com/ssut/py-hanspell.git
# !pip install konlpy
# !pip install krwordrank

from hanspell import spell_checker
from tqdm.notebook import tqdm
from konlpy.tag import Twitter
from collections import Counter
from krwordrank.hangle import normalize


nlpy = Twitter()

lines = [line.rstrip('\n') for line in texts] #txt 파일을 개행문자 기준으로 splig

nouns_word = [] #명사 단어 추출
normalized_lines = []
for each_line in tqdm(lines):
    each_line = each_line.replace("\x0c", "") #json을 로드 하면서 생기는 특수문자 제거
    each_line = normalize(each_line, english=True, number=True) #특수문자 제거
    each_line = spell_checker.check(each_line).checked #맞춤법 틀린게 있다면 고쳐줌
    nouns_word = nouns_word + nlpy.nouns(each_line) # 명사 단어 추출
    normalized_lines.append(each_line)
# Out:
# Collecting git+https://github.com/ssut/py-hanspell.git
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-gomrardk
#   Running command git clone -q https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-gomrardk
# Requirement already satisfied (use --upgrade to upgrade): py-hanspell==1.1 from git+https://github.com/ssut/py-hanspell.git in /usr/local/lib/python3.7/dist-packages
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from py-hanspell==1.1) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->py-hanspell==1.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->py-hanspell==1.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->py-hanspell==1.1) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->py-hanspell==1.1) (2.10)
# Building wheels for collected packages: py-hanspell
#   Building wheel for py-hanspell (setup.py) ... done
#   Created wheel for py-hanspell: filename=py_hanspell-1.1-cp37-none-any.whl size=4871 sha256=1e2d6fcacb90aa06e6f72b0b24afa7d7193ae64f56cf14f43a369a62c0e3f5c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qhzn8pfc/wheels/0a/25/d1/e5e96476dbb1c318cc26c992dd493394fe42b0c204b3e65588
# Successfully built py-hanspell
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.2.1)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: krwordrank in /usr/local/lib/python3.7/dist-packages (1.0.3)
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.7/dist-packages (from krwordrank) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from krwordrank) (1.4.1)
# Requirement already satisfied: numpy>=1.18.4 in /usr/local/lib/python3.7/dist-packages (from krwordrank) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.1->krwordrank) (1.0.1)
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# HBox(children=(FloatProgress(value=0.0, max=40.0), HTML(value='')))

# %%
normalized_lines
# Out:
# ['1 중앙군 5 위 5 군영 체제로 전환 서인 정권의 군사적 기반으로 활용',
#  '2 5 군영 17세기 말에 체제가 갖추어짐',
#  '',
#  '훈련도감 선조 때 직업적 상비군 서물의 경비 담당 삼수병 포수 사수',
#  '수로 구성',
#  '',
#  '0 머영청 총융청 수어청 인조 때 서인의 군사적 기반 경기도 지방 방어',
#  '9 금위영 숙종 때 수도 방어 임무',
#  '3 지방 방어 체제 진관 체제 제승 방략 체제 진관 복구 속오군 설치',
#  '4 수취 제도의 개편',
#  '1 배경 지주제 강화와 과중한 부사로 농민 몰락',
#  '0 수취 제도 개혁 영정법 전세 대동법 공납 균역법 군역',
#  '9 결과 지주들의 부담 전가 각종 부가세 증가로 농민 부담여',
#  '2 향촌 지배 방식 사족 지배 체제에서 수령 향리 중심으로 전환',
#  '3 농민 이탈 방지책 호패법 오가작통법 강화',
#  '',
#  '2 정쟁의 격화와 탕평 정치',
#  '1 붕당 정치의 변질',
#  '1 배경 상업적 이익을 독점하려는 경향 정치적 쟁점의 변화 군영 장악',
#  '지주제와 신분제의 동요 붕당 정치의 기반 붕괴',
#  '2 과정 왕이 직접 환국 주도 일당 전제화의 추세',
#  '3 결과 왕실 외척 종실 역할 중대 3 사 이조 전랑 비중 축소 비변사 기능 강화',
#  '2 탕평 정치',
#  '1 탕평론의 대두',
#  '0 배경 붕당 정치의 변질로 왕권 불안 강한 왕권으로 세력의 균형 유지',
#  '0 숙종의 탕평론 명목상의 탕평론 환국 초래 노론 소론의 대립 격화',
#  '2 영조의 탕평 정치',
#  '0 탕평 교서 발표 노론과 소론을 교대로 등용 이인좌의 난 발생',
#  '0 탕 펴 파 중심의 운영 산림의 존재 부정 서먼의 대폭 정리 이조 전랑의',
#  '자천권 및 3 사관뭔의 선발 관행 폐지 국 옹과 탕평파 대신에게 권력 집중',
#  '',
#  '개혁 추진 균역법 시행 1750 도성 방위 분담 체제 정비 가혹한',
#  '형벌 폐지 사형수에 대한 삼 심제의 엄격한 시행 속대전 편찬',
#  '3 정조의 탕평 정치 척신 환관 세력 제거 남인 계열 중용',
#  '0 왕권 강화 규장각 설치 장용영 설치 초계문신제 신진 인물 중 하급 관리',
#  '재교 붕당을 초월한 인재 등용',
#  '0 지방 통치 수령의 권한 대폭 증대 군현 단위의 향약을 수령이 주관',
#  '지방 사족의 발호 억제 국가의 백성에 대한 통치력',
#  '9 시파와 벽파 영조 때 사도세자의 폐위와 사사를 둘러싸고 분열된',
#  '']

# %%
# 명사의 빈도수 계산
from collections import Counter
count = Counter(nouns_word)

tag_count = []
tags = []

#길이가 2부터 49까지인 단어 
for n, c in count.most_common():
  dics = {'tag': n, 'count': c}
  if len(dics['tag']) >= 2 and len(tags) <= 49:
    tag_count.append(dics)
    tags.append(dics['tag'])

# %%
import pandas as pd
noun_count_df = pd.DataFrame(tag_count)

# %%
#명사 중 가장 긴 단어의 문자열 길이 
print("최장 단어 길이 ", max(noun_count_df["tag"].str.len()))
#명사 중 최소 출현 빈도 수
print("최소 출현 빈도 수 ", min(noun_count_df["count"]))
# Out:
# 최장 단어 길이  4
# 최소 출현 빈도 수  1

# %%
frequency_noun_list = noun_count_df[noun_count_df["count"]>0]["tag"].tolist()

# %%
from krwordrank.word import KRWordRank

wordrank_extractor = KRWordRank(
    min_count = min(noun_count_df["count"]), # 단어의 최소 출현 빈도수
    max_length = max(noun_count_df["tag"].str.len()), # 단어의 최대 길이
    verbose = True
    )

beta = 0.85    # PageRank의 decaying factor beta
max_iter = 10

#keywords는 filtering이 적용된 L parts
#rank는 substriing graph의 substring에 대한 구마
#graph는 substring graph
keywords, rank, graph = wordrank_extractor.extract(normalized_lines, beta, max_iter)
# Out:
# scan vocabs ...
# num vocabs = 663
# done

# %%
keyword_df = pd.DataFrame(list(keywords.items()),columns=['word', 'rank'])

# %%
keyword_list = keyword_df["word"].tolist()

# %%
test_by_frequency_noun = []
for each_line in lines:
    for word in each_line.split():
        if word in frequency_noun_list:
            each_line = each_line.replace(word, "□"*len(word))
    test_by_frequency_noun.append(each_line)

# %%
test_by_frequency_noun
# Out:
# ['1) 중앙군 : 5 위 ->*5 □□ 체제로 전환, □□ 정권의 군사적 기반으로 □□',
#  '2) 5 □□ :17세기 말에 체제가 갖추어 짐',
#  '',
#  '~ 훈련도감(선조때) : 직업적 상비군, 서물의 경비 담당, 삼수병(포수, 사수,',
#  '수)로 구성',
#  '',
#  '0: 머영청. 총융청. 수어청(인조때) :서인의 군사적 기반, 경기도 □□ □□',
#  '9) 금위영(숙종때): 수도 □□ 임무',
#  '3) □□ □□ □□ : □□ □□ -> 제승 방략 □□ - □□ 복구, 속오군 □□',
#  '4. □□ 제도의 개편',
#  '1) □□ : 지주제 강화와 과중한 부세로 □□ 몰락',
#  '0) □□ □□ □□ : 영정법(전세), 대동법(공납), 균역법((군역)',
#  '9) □□ : 지주들의 □□ 전가, 각종 부가세 증가로 □□ □□ 여',
#  '2) 항촌 □□ 방식 : □□ □□ 체제에서 수령. 향리 중심으로 □□',
#  '3) □□ 이탈 방지책 : 호패법, 오가작통법 □□',
#  '',
#  '<2> 정쟁의 격화와 □□ □□',
#  '1. □□ 정치의 □□',
#  '1) □□ : 상업적 이익을 독점하려는 경향, 정치적 쟁점의 변화(군영 장악),',
#  '지주제와 신분제의 동요 - □□ 정치의 □□ 붕괴',
#  '2) 과정 : 왕이 직접 □□ 주도 * 일당 전제화의 추세',
#  '3) □□ : 왕실 외척. 종실 역할 중대, 3 사. □□ □□ 비중 축소, 비변사 기능강화',
#  '2. □□ □□',
#  '1) 탕평론의 대두',
#  '0 □□ : □□ 정치의 변질로 □□ 불안 -+ 강한 □□으로 세력의 균형 유지',
#  '0 숙종의 탕평론 : 명목상의 탕평론 -* □□ 초래, 노론. 소론의 대립 □□',
#  '2) 영조의 □□ □□',
#  '0 □□ 교서 발표 : 노론과 소론을 교대로 □□ - 이인좌의 난 발생',
#  '0 탕펴파 중심의 운영 : 산림의 존재 부정, 서뭔의 □□ 정리, □□ 전랑의',
#  '자천권및 3 사관뭔의 선발 관행 □□ > 국옹과 탕평파 대신에게 권력 집중',
#  '',
#  '@ □□ 추진 : □□□ 시행(1750), 도성 방위 분담 □□ 정비, 가혹한',
#  '형벌폐지, 사형수에 □□ 삼심제의 엄격한 □□ - 속대전 편찬',
#  '3) 정조의 □□ □□ : 척신. 환관 □□ 제거, 남인 계열 중용',
#  '0 □□ □□ : 규장각 설치, 장용영 설치, 초계문신제(신진 인물, 중.하급 관리',
#  '재교), 붕당을 초월한 인재 □□',
#  '0 □□ □□ : 수령의 권한 □□ 증대, 군현 단위의 향약을 수령이 주관 -',
#  '지방사족의 발호 억제, 국가의 백성에 □□ 통치력',
#  '9 시파와 벽파 : 영조때 사도세자의 폐위와 사사를 둘러싸고 분열된',
#  '\x0c']

# %%
test_by_keyword = []
for each_line in lines:
    for word in each_line.split():
        if word in keyword_list:
            each_line = each_line.replace(word, "□"*len(word))
    test_by_keyword.append(each_line)

# %%
test_by_keyword
# Out:
# ['1) 중앙군 : 5 위 ->*5 □□ 체제로 전환, □□ □□□ □□□ 기반으로 □□',
#  '2) 5 □□ :17세기 □□ 체제가 갖추어 짐',
#  '',
#  '~ 훈련도감(선조때) : □□□ 상비군, □□□ □□ 담당, 삼수병(포수, 사수,',
#  '수)로 □□',
#  '',
#  '0: 머영청. 총융청. 수어청(인조때) :서인의 □□□ 기반, □□□ □□ □□',
#  '9) 금위영(숙종때): □□ □□ □□',
#  '3) □□ □□ □□ : □□ □□ -> □□ □□ □□ - □□ 복구, □□□ □□',
#  '4. □□ 제도의 □□',
#  '1) □□ : 지주제 강화와 □□□ 부세로 □□ □□',
#  '0) □□ □□ □□ : 영정법(전세), 대동법(공납), 균역법((군역)',
#  '9) □□ : 지주들의 □□ 전가, □□ □□□ □□□ □□ □□ 여',
#  '2) 항촌 □□ □□ : □□ □□ 체제에서 수령. □□ 중심으로 □□',
#  '3) □□ □□ □□□ : 호패법, □□□□□ □□',
#  '',
#  '<2> □□□ 격화와 □□ □□',
#  '1. □□ 정치의 □□',
#  '1) □□ : □□□ □□□ □□□□□ 경향, 정치적 □□□ 변화(군영 장악),',
#  '지주제와 □□□□ □□ - □□ 정치의 □□ □□',
#  '2) □□ : □□ □□ □□ □□ * □□ 전제화의 □□',
#  '3) □□ : □□ 외척. □□ □□ 중대, 3 사. □□ □□ □□ 축소, 비변사 기능강화',
#  '2. □□ □□',
#  '1) 탕평론의 □□',
#  '0 □□ : □□ 정치의 변질로 □□ □□ -+ □□ □□으로 □□□ □□ □□',
#  '0 숙종의 탕평론 : □□□□ 탕평론 -* □□ 초래, 노론. 소론의 □□ □□',
#  '2) 영조의 □□ □□',
#  '0 □□ □□ □□ : 노론과 □□□ □□□ □□ - 이인좌의 난 발생',
#  '0 탕펴파 중심의 □□ : □□□ □□ 부정, 서뭔의 □□ 정리, □□ 전랑의',
#  '자천권및 3 사관뭔의 □□ □□ □□ > 국옹과 탕평파 □□□□ □□ □□',
#  '',
#  '@ □□ □□ : □□□ 시행(1750), □□ □□ □□ □□ 정비, 가혹한',
#  '형벌폐지, 사형수에 □□ 삼심제의 □□□ □□ - □□□ □□',
#  '3) 정조의 □□ □□ : 척신. □□ 세력 제거, □□ □□ □□',
#  '0 □□ □□ : 규장각 설치, 장용영 설치, 초계문신제(신진 인물, 중.하급 □□',
#  '재교), 붕당을 □□□ □□ □□',
#  '0 □□ □□ : 수령의 □□ □□ 증대, □□ □□□ □□□ 수령이 □□ -',
#  '지방사족의 □□ 억제, □□□ □□□ □□ 통치력',
#  '9 시파와 □□ : 영조때 □□□□□ □□□ □□□ □□□□ □□□',
#  '\x0c']

# %%
test_restrict_count = []
for each_line in lines:
    replace_word = []
    for word in each_line.split(' '):
        if word in keyword_list:
            replace_word.append(word)

    #한 문장에 빈칸이 3개 이상일때
    if len(replace_word) > 2:
        A = pd.DataFrame()
        pattern = '|'.join(replace_word)
        A = keyword_df[keyword_df['word'].str.contains(pattern, case=False)]
        replace_word = A[:3].word

    for i in replace_word:
        each_line = each_line.replace(i,"□"*len(i))

    test_restrict_count.append(each_line)

# %%
test_restrict_count
# Out:
# ['1) 중앙군 : 5 위 ->*5 □□ 체제로 전환, □□ 정권의 □□□ 기반으로 활용',
#  '2) 5 □□ :17세기 □□ 체제가 갖추어 짐',
#  '',
#  '~ 훈련도감(선조때) : □□□ 상비군, □□□ □□ 담당, 삼수병(포수, 사수,',
#  '수)로 □□',
#  '',
#  '0: 머영청. 총융청. 수어청(인조때) :서인의 □□□ 기반, 경기도 □□ □□',
#  '9) 금위영(숙종때): □□ □□ □□',
#  '3) □□ 방어 □□ : 진관 □□ -> 제승 방략 □□ - 진관 복구, 속오군 □□',
#  '4. □□ 제도의 □□',
#  '1) □□ : 지주제 강화와 □□□ 부세로 □□ 몰락',
#  '0) □□ □□ □□ : 영정법(전세), 대동법(공납), 균역법((군역)',
#  '9) □□ : 지주들의 □□ 전가, 각종 부가세 증가로 □□ □□ 여',
#  '2) 항촌 □□ 방식 : 사족 □□ 체제에서 수령. □□ 중심으로 □□',
#  '3) □□ 이탈 □□□ : 호패법, 오가작통법 □□',
#  '',
#  '<2> □□□ 격화와 □□ □□',
#  '1. □□ 정치의 □□',
#  '1) □□ : 상업적 □□□ □□□□□ 경향, 정치적 쟁점의 변화(군영 장악),',
#  '지주제와 □□□□ 동요 - □□ 정치의 □□ 붕괴',
#  '2) 과정 : 왕이 직접 □□ 주도 * □□ 전제화의 □□',
#  '3) □□ : 왕실 외척. □□ 역할 중대, 3 사. 이조 □□ 비중 축소, 비변사 기능강화',
#  '2. □□ □□',
#  '1) 탕평론의 □□',
#  '0 □□ : □□ 정치의 변질로 □□ 불안 -+ 강한 □□으로 세력의 균형 유지',
#  '0 숙종의 탕평론 : □□□□ 탕평론 -* □□ 초래, 노론. 소론의 대립 □□',
#  '2) 영조의 □□ □□',
#  '0 □□ 교서 발표 : 노론과 □□□ 교대로 □□ - 이인좌의 난 발생',
#  '0 탕펴파 중심의 □□ : 산림의 존재 부정, 서뭔의 □□ 정리, □□ 전랑의',
#  '자천권및 3 사관뭔의 □□ 관행 □□ > 국옹과 탕평파 대신에게 □□ 집중',
#  '',
#  '@ □□ 추진 : 균역법 시행(1750), □□ 방위 분담 □□ 정비, 가혹한',
#  '형벌폐지, 사형수에 □□ 삼심제의 엄격한 □□ - 속대전 □□',
#  '3) 정조의 □□ □□ : 척신. 환관 세력 제거, □□ 계열 중용',
#  '0 □□ □□ : 규장각 설치, 장용영 설치, 초계문신제(신진 인물, 중.하급 □□',
#  '재교), 붕당을 □□□ □□ □□',
#  '0 □□ □□ : 수령의 권한 □□ 증대, 군현 단위의 향약을 수령이 주관 -',
#  '지방사족의 □□ 억제, □□□ 백성에 □□ 통치력',
#  '9 시파와 벽파 : 영조때 사도세자의 □□□ □□□ □□□□ 분열된',
#  '\x0c']

# %%
lines
# Out:
# ['1) 중앙군 : 5 위 ->*5 군영 체제로 전환, 서인 정권의 군사적 기반으로 활용',
#  '2) 5 군영 :17세기 말에 체제가 갖추어 짐',
#  '',
#  '~ 훈련도감(선조때) : 직업적 상비군, 서물의 경비 담당, 삼수병(포수, 사수,',
#  '수)로 구성',
#  '',
#  '0: 머영청. 총융청. 수어청(인조때) :서인의 군사적 기반, 경기도 지방 방어',
#  '9) 금위영(숙종때): 수도 방어 임무',
#  '3) 지방 방어 체제 : 진관 체제 -> 제승 방략 체제 - 진관 복구, 속오군 설치',
#  '4. 수취 제도의 개편',
#  '1) 배경 : 지주제 강화와 과중한 부세로 농민 몰락',
#  '0) 수취 제도 개혁 : 영정법(전세), 대동법(공납), 균역법((군역)',
#  '9) 결과 : 지주들의 부담 전가, 각종 부가세 증가로 농민 부담 여',
#  '2) 항촌 지배 방식 : 사족 지배 체제에서 수령. 향리 중심으로 전환',
#  '3) 농민 이탈 방지책 : 호패법, 오가작통법 강화',
#  '',
#  '<2> 정쟁의 격화와 탕평 정치',
#  '1. 붕당 정치의 변질',
#  '1) 배경 : 상업적 이익을 독점하려는 경향, 정치적 쟁점의 변화(군영 장악),',
#  '지주제와 신분제의 동요 - 붕당 정치의 기반 붕괴',
#  '2) 과정 : 왕이 직접 환국 주도 * 일당 전제화의 추세',
#  '3) 결과 : 왕실 외척. 종실 역할 중대, 3 사. 이조 전랑 비중 축소, 비변사 기능강화',
#  '2. 탕평 정치',
#  '1) 탕평론의 대두',
#  '0 배경 : 붕당 정치의 변질로 왕권 불안 -+ 강한 왕권으로 세력의 균형 유지',
#  '0 숙종의 탕평론 : 명목상의 탕평론 -* 환국 초래, 노론. 소론의 대립 격화',
#  '2) 영조의 탕평 정치',
#  '0 탕평 교서 발표 : 노론과 소론을 교대로 등용 - 이인좌의 난 발생',
#  '0 탕펴파 중심의 운영 : 산림의 존재 부정, 서뭔의 대폭 정리, 이조 전랑의',
#  '자천권및 3 사관뭔의 선발 관행 폐지 > 국옹과 탕평파 대신에게 권력 집중',
#  '',
#  '@ 개혁 추진 : 균역법 시행(1750), 도성 방위 분담 체제 정비, 가혹한',
#  '형벌폐지, 사형수에 대한 삼심제의 엄격한 시행 - 속대전 편찬',
#  '3) 정조의 탕평 정치 : 척신. 환관 세력 제거, 남인 계열 중용',
#  '0 왕권 강화 : 규장각 설치, 장용영 설치, 초계문신제(신진 인물, 중.하급 관리',
#  '재교), 붕당을 초월한 인재 등용',
#  '0 지방 통치 : 수령의 권한 대폭 증대, 군현 단위의 향약을 수령이 주관 -',
#  '지방사족의 발호 억제, 국가의 백성에 대한 통치력',
#  '9 시파와 벽파 : 영조때 사도세자의 폐위와 사사를 둘러싸고 분열된',
#  '\x0c']
